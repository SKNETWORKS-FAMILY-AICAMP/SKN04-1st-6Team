# %% [markdown]
# # ⚠️ ERROR 일지
#
# ### FAQ 크롤링
# <br/>
#
#
# #### 👉 자동차 등록대수 현황 API 크롤링
# ##### 자동차등록대수
#
# **자동차등록대수**
# > 문제 : kosis open api crawling 과정에서 응답필드 구분과 끌어오지 않은 것들이 들어오는 문제가 발생
# >
# > 해결 : 노가다와 반복문을 돌며 예외처리하여 해결함
#
# #### 👉 FAQ 2개기업 사이트 크롤링
#
# ##### 기아 FAQ
# **기아 FAQ**
#
# > 문제 : 크롤링 중 일어나는 버그의 위치가 명확하지 않음.
# >
# > 해결 : 함수 안에 각 기능을 모두 함수화 한 뒤, False를 반환하게 하고 그 기능에서 문제가 발생했다면 그 함수의 이름을 print하도록 함
#
# ##### 현대 FAQ
#
# **1. 정적 크롤링(request) 선택의 문제**
# > 문제 : 질문 드롭다운 & 카테고리 리스트 클릭과 같은 사용자 동작이 필요하여
# > 정적 크롤링으로 처리할 수 없었음
# >
# > 해결 : 동적 크롤링(selenium)을 사용
#
# **2. 화면 크기에 따라 pagenation 번호 상이**
# > 문제 : 화면 접근 시 page번호가 화면 크기에 따라서 번호가 다르게 나타남
# >
# > 해결 : 화면 크기를 1980*1080으로 해상도 고정하여 화면 크기를 표준화함
#
# **3. 홈페이지 내 태그 요소 인식 불가**
# > 문제 : 특정 요소를 클릭하려고 할 때, 해당 요소가 존재하지 않거나
# > 인식되지 않는 문제 발생
# >
# > 해결 : 'WebDriverWait'를 활용하여 실제 존재하고 클릭이 가능할 때까지 대기하도록 구현
#
# **4. 마지막 페이지 도착 후 상단 카테고리 선택 불가**
# > 문제 : 마지막 페이지 도착 후 다음 카테고리 선택이 안되는 문제 발생,
# > 'click()'를 사용하였지만 화면에 가려져 보이지 않아서 작동되지 않음
# >
# > 해결 : .click() 함수 대신 javascript 버튼 동작으로 강제 클릭되도록 수행
#
#
# <br/>
#
# #### 👉 데이터 베이스 구축
#
# **DB명**
# > 문제 : 기존의 db가 존재하는 상태에서 db를 넣을때 우선 키와 왜래 키 때문에 에러 발생
#
# > 해결 : db를 넣기전 drop table로 테이블 삭제 cascade 옵션을 써서 종속성 해제
#
# <br/>
#
# #### 👉 streamlit 페이지 구성
# **streamlit**
# > 문제 : 표로 끌어오는 작업은 어렵지않게 했으나 크롤링 과정에서 count를 정수로 받아오지못해 억단위로 나오는 문제가 발생
# >
# > 해결 : pd.to_numeric 씌워서 해결함
#
#
# <br/>
